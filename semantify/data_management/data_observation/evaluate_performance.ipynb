# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

main_dir = "/home/nadav2/dev/data/CLIP2Shape/outs/descriptors_ablations/correct_threshold/smplx_male"

to_compare_dirs = ["smplx_male_2_descriptors", "smplx_male_5_descriptors", "smplx_male_e2e", "smplx_male_10_descriptors", "smplx_male_15_descriptors", "smplx_male_18_descriptors"]
production_dir = "smplx_male_e2e"
results_dict = {"iou": [], "num_of_descriptors": [], "overlap": []}
for to_compare_dir in to_compare_dirs:
    with open(Path(main_dir) / to_compare_dir /  "descriptors.json", "r") as f:
        data = json.load(f)
    results_dict["iou"].append(data["iou"]  * 100)
    results_dict["num_of_descriptors"].append(data["labels"].__len__())
    results_dict["overlap"].append(data["overlap"] * 100)
    if to_compare_dir == production_dir:
        production_iou = data["iou"] * 100
        production_num_of_descriptors = data["labels"].__len__()
        production_overlap = data["overlap"] * 100


# plot the results, x axis is the number of descriptors, y axis is the iou
plt.figure(figsize=(10, 5))
plt.plot(results_dict["num_of_descriptors"], results_dict["iou"], label="vertices coverage", color="blue")
plt.plot(results_dict["num_of_descriptors"], results_dict["overlap"], label="overlap", color="green")
plt.xticks(results_dict["num_of_descriptors"].remove(production_num_of_descriptors))
plt.yticks(np.arange(0, 101, 20), labels=[f"{i}%" for i in np.arange(0, 101, 20)])
plt.axvline(x=production_num_of_descriptors, color="red", linestyle="--", alpha=0.3, label="without limit")
plt.annotate(f"{production_num_of_descriptors} descriptors\n{production_iou:.2f}% vertices coverage\n{production_overlap:.2f}% overlap", (production_num_of_descriptors+0.5, production_iou-3.0))
plt.xlabel("# Descriptors")
plt.legend()
plt.title("Performance by # Descriptors - SMPLX male")
plt.tight_layout()

# save the plot
plt.savefig(Path(main_dir) / "descriptors_vs_coverage.png")

# %%
import pandas as pd

results_dict
# Out:
# {'iou': [38.68843069873998,
#   51.55593738067965,
#   92.11531118747614,
#   49.76135929744177,
#   98.37724322260405,
#   89.97709049255441],
#  'num_of_descriptors': [2, 5, 10, 15, 18],
#  'overlap': [30.19290389252497,
#   71.4489612517841,
#   64.56765191848723,
#   83.52089523929949,
#   80.55655126874824,
#   84.66020049472725]}

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

main_dir = "/home/nadav2/dev/data/CLIP2Shape/outs/descriptors_ablations/correct_threshold/smplx_female"

to_compare_dirs = ["smplx_female_2_descriptors", "smplx_female", "smplx_female_5_descriptors", "smplx_female_10_descriptors", "smplx_female_15_descriptors"]
production_dir = "smplx_female"
results_dict = {"iou": [], "num_of_descriptors": [], "overlap": []}
for to_compare_dir in to_compare_dirs:
    with open(Path(main_dir) / to_compare_dir /  "descriptors.json", "r") as f:
        data = json.load(f)
    results_dict["iou"].append(data["iou"]  * 100)
    results_dict["num_of_descriptors"].append(data["labels"].__len__())
    results_dict["overlap"].append(data["overlap"] * 100)
    if to_compare_dir == production_dir:
        production_iou = data["iou"] * 100
        production_num_of_descriptors = data["labels"].__len__()
        production_overlap = data["overlap"] * 100


# plot the results, x axis is the number of descriptors, y axis is the iou
plt.figure(figsize=(10, 5))
plt.plot(results_dict["num_of_descriptors"], results_dict["iou"], label="vertices coverage", color="blue")
plt.plot(results_dict["num_of_descriptors"], results_dict["overlap"], label="overlap", color="green")
plt.xticks(results_dict["num_of_descriptors"].remove(production_num_of_descriptors))
plt.yticks(np.arange(0, 101, 20), labels=[f"{i}%" for i in np.arange(0, 101, 20)])
plt.axvline(x=production_num_of_descriptors, color="red", linestyle="--", alpha=0.3, label="without limit")
plt.annotate(f"{production_num_of_descriptors} descriptors\n{production_iou:.2f}% vertices coverage\n{production_overlap:.2f}% overlap", (production_num_of_descriptors+0.5, production_iou))
plt.xlabel("# Descriptors")
plt.legend()
plt.title("Performance by # Descriptors - SMPLX female")
plt.tight_layout()

# save the plot
plt.savefig(Path(main_dir) / "descriptors_vs_coverage.png")

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

main_dir = "/home/nadav2/dev/data/CLIP2Shape/outs/descriptors_ablations/correct_threshold/smplx_neutral"

to_compare_dirs = ["smplx_neutral_2_descriptors", "smplx_neutral_5_descriptors", "smplx_neutral", "smplx_neutral_10_descriptors", "smplx_neutral_15_descriptors", "smplx_neutral_20_descriptors"]
production_dir = "smplx_neutral"
results_dict = {"iou": [], "num_of_descriptors": [], "overlap": []}
for to_compare_dir in to_compare_dirs:
    with open(Path(main_dir) / to_compare_dir /  "descriptors.json", "r") as f:
        data = json.load(f)
    results_dict["iou"].append(data["iou"]  * 100)
    results_dict["num_of_descriptors"].append(data["labels"].__len__())
    results_dict["overlap"].append(data["overlap"] * 100)
    if to_compare_dir == production_dir:
        production_iou = data["iou"] * 100
        production_num_of_descriptors = data["labels"].__len__()
        production_overlap = data["overlap"] * 100


# plot the results, x axis is the number of descriptors, y axis is the iou
plt.figure(figsize=(10, 5))
plt.plot(results_dict["num_of_descriptors"], results_dict["iou"], label="vertices coverage", color="blue")
plt.plot(results_dict["num_of_descriptors"], results_dict["overlap"], label="overlap", color="green")
plt.xticks(results_dict["num_of_descriptors"].remove(production_num_of_descriptors))
plt.yticks(np.arange(0, 101, 20), labels=[f"{i}%" for i in np.arange(0, 101, 20)])
plt.axvline(x=production_num_of_descriptors, color="red", linestyle="--", alpha=0.3, label="without limit")
plt.annotate(f"{production_num_of_descriptors} descriptors\n{production_iou:.2f}% vertices coverage\n{production_overlap:.2f}% overlap", (production_num_of_descriptors+0.5, production_iou))
plt.xlabel("# Descriptors")
plt.legend()
plt.title("Performance by # Descriptors - SMPLX nuetral")
plt.tight_layout()

# save the plot
plt.savefig(Path(main_dir) / "descriptors_vs_coverage.png")

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

main_dir = "/home/nadav2/dev/data/CLIP2Shape/outs/descriptors_ablations/correct_threshold/smpl_male"

to_compare_dirs = ["smpl_male_2_descriptors", "smpl_male", "smpl_male_5_descriptors", "smpl_male_10_descriptors", "smpl_male_15_descriptors", "smpl_male_17_descriptors"]
production_dir = "smpl_male"
results_dict = {"iou": [], "num_of_descriptors": [], "overlap": []}
for to_compare_dir in to_compare_dirs:
    with open(Path(main_dir) / to_compare_dir /  "descriptors.json", "r") as f:
        data = json.load(f)
    results_dict["iou"].append(data["iou"]  * 100)
    results_dict["num_of_descriptors"].append(data["labels"].__len__())
    results_dict["overlap"].append(data["overlap"] * 100)
    if to_compare_dir == production_dir:
        production_iou = data["iou"] * 100
        production_num_of_descriptors = data["labels"].__len__()
        production_overlap = data["overlap"] * 100


# plot the results, x axis is the number of descriptors, y axis is the iou
plt.figure(figsize=(10, 5))
plt.plot(results_dict["num_of_descriptors"], results_dict["iou"], label="vertices coverage", color="blue")
plt.plot(results_dict["num_of_descriptors"], results_dict["overlap"], label="overlap", color="green")
plt.xticks(results_dict["num_of_descriptors"].remove(production_num_of_descriptors))
plt.yticks(np.arange(0, 101, 20), labels=[f"{i}%" for i in np.arange(0, 101, 20)])
plt.axvline(x=production_num_of_descriptors, color="red", linestyle="--", alpha=0.3, label="without limit")
plt.annotate(f"{production_num_of_descriptors} descriptors\n{production_iou:.2f}% vertices coverage\n{production_overlap:.2f}% overlap", (production_num_of_descriptors+0.5, production_iou-15.0))
plt.xlabel("# Descriptors")
plt.legend()
plt.title("Performance by # Descriptors - SMPL male")
plt.tight_layout()

# save the plot
plt.savefig(Path(main_dir) / "descriptors_vs_coverage.png")

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

main_dir = "/home/nadav2/dev/data/CLIP2Shape/outs/descriptors_ablations/smpl_female"

to_compare_dirs = ["smpl_female_2_descriptors", "smpl_female_e2e", "smpl_female_10_descriptors", "smpl_female_15_descriptors"]
production_dir = "smpl_female_e2e"
results_dict = {"iou": [], "num_of_descriptors": [], "overlap": []}
for to_compare_dir in to_compare_dirs:
    with open(Path(main_dir) / to_compare_dir /  "descriptors.json", "r") as f:
        data = json.load(f)
    results_dict["iou"].append(data["iou"]  * 100)
    results_dict["num_of_descriptors"].append(data["labels"].__len__())
    results_dict["overlap"].append(data["overlap"] * 100)
    if to_compare_dir == production_dir:
        production_iou = data["iou"] * 100
        production_num_of_descriptors = data["labels"].__len__()
        production_overlap = data["overlap"] * 100


# plot the results, x axis is the number of descriptors, y axis is the iou
plt.figure(figsize=(10, 5))
plt.plot(results_dict["num_of_descriptors"], results_dict["iou"], label="vertices coverage", color="blue")
plt.plot(results_dict["num_of_descriptors"], results_dict["overlap"], label="overlap", color="green")
plt.xticks(results_dict["num_of_descriptors"].remove(production_num_of_descriptors))
plt.yticks(np.arange(0, 101, 20), labels=[f"{i}%" for i in np.arange(0, 101, 20)])
plt.axvline(x=production_num_of_descriptors, color="red", linestyle="--", alpha=0.3, label="without limit")
plt.annotate(f"{production_num_of_descriptors} descriptors\n{production_iou:.2f}% vertices coverage\n{production_overlap:.2f}% overlap", (production_num_of_descriptors+0.5, production_iou-15.0))
plt.xlabel("# Descriptors")
plt.legend()
plt.title("Performance by # Descriptors - SMPL female")
plt.tight_layout()

# save the plot
plt.savefig(Path(main_dir) / "descriptors_vs_coverage.png")

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

main_dir = "/home/nadav2/dev/data/CLIP2Shape/outs/descriptors_ablations/flame_shape"

to_compare_dirs = ["flame_neutral_2_descriptors", "flame_shape_e2e", "flame_neutral_6_descriptors", "flame_neutral_7_descriptors"]
production_dir = "flame_shape_e2e"
results_dict = {"iou": [], "num_of_descriptors": [], "overlap": []}
for to_compare_dir in to_compare_dirs:
    with open(Path(main_dir) / to_compare_dir /  "descriptors.json", "r") as f:
        data = json.load(f)
    results_dict["iou"].append(data["iou"]  * 100)
    results_dict["num_of_descriptors"].append(data["labels"].__len__())
    results_dict["overlap"].append(data["overlap"] * 100)
    if to_compare_dir == production_dir:
        production_iou = data["iou"] * 100
        production_num_of_descriptors = data["labels"].__len__()
        production_overlap = data["overlap"] * 100


# plot the results, x axis is the number of descriptors, y axis is the iou
plt.figure(figsize=(10, 5))
plt.plot(results_dict["num_of_descriptors"], results_dict["iou"], label="vertices coverage", color="blue")
plt.plot(results_dict["num_of_descriptors"], results_dict["overlap"], label="overlap", color="green")
plt.xticks(results_dict["num_of_descriptors"].remove(production_num_of_descriptors))
plt.yticks(np.arange(0, 101, 20), labels=[f"{i}%" for i in np.arange(0, 101, 20)])
plt.axvline(x=production_num_of_descriptors, color="red", linestyle="--", alpha=0.3, label="without limit")
plt.annotate(f"{production_num_of_descriptors} descriptors\n{production_iou:.2f}% vertices coverage\n{production_overlap:.2f}% overlap", (production_num_of_descriptors+0.5, production_iou))
plt.xlabel("# Descriptors")
plt.legend()
plt.title("Performance by # Descriptors - FLAME shape")
plt.tight_layout()

# save the plot
plt.savefig(Path(main_dir) /  "descriptors_vs_coverage.png")

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

main_dir = "/home/nadav2/dev/data/CLIP2Shape/outs/descriptors_ablations/flame_expression"

to_compare_dirs = ["flame_neutral_2_descriptors", "flame_expression_e2e", "flame_neutral_5_descriptors", "flame_neutral_10_descriptors", "flame_neutral_15_descriptors", "flame_neutral_20_descriptors"]
production_dir = "flame_expression_e2e"
results_dict = {"iou": [], "num_of_descriptors": [], "overlap": []}
for to_compare_dir in to_compare_dirs:
    with open(Path(main_dir) / to_compare_dir /  "descriptors.json", "r") as f:
        data = json.load(f)
    results_dict["iou"].append(data["iou"]  * 100)
    results_dict["num_of_descriptors"].append(data["labels"].__len__())
    results_dict["overlap"].append(data["overlap"] * 100)
    if to_compare_dir == production_dir:
        production_iou = data["iou"] * 100
        production_num_of_descriptors = data["labels"].__len__()
        production_overlap = data["overlap"] * 100


# plot the results, x axis is the number of descriptors, y axis is the iou
plt.figure(figsize=(10, 5))
plt.plot(results_dict["num_of_descriptors"], results_dict["iou"], label="vertices coverage", color="blue")
plt.plot(results_dict["num_of_descriptors"], results_dict["overlap"], label="overlap", color="green")
plt.xticks(results_dict["num_of_descriptors"].remove(production_num_of_descriptors))
plt.yticks(np.arange(0, 101, 20), labels=[f"{i}%" for i in np.arange(0, 101, 20)])
plt.axvline(x=production_num_of_descriptors, color="red", linestyle="--", alpha=0.3, label="without limit")
plt.annotate(f"{production_num_of_descriptors} descriptors\n{production_iou:.2f}% vertices coverage\n{production_overlap:.2f}% overlap", (production_num_of_descriptors+0.5, production_iou))
plt.xlabel("# Descriptors")
plt.legend()
plt.title("Performance by # Descriptors - FLAME expression")
plt.tight_layout()

# save the plot
plt.savefig(Path(main_dir) /  "descriptors_vs_coverage.png")
