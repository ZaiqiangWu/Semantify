# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path


data_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/images_to_fit/smplx/male")
working_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/smplx_male/descriptors_ablations")

# %%
data_summary = {}
for pipeline in working_dir.iterdir():
    if pipeline.stem not in data_summary:
        data_summary[pipeline.stem] = {"geo_dist": [], "num_steps": []}
    for file in pipeline.rglob("*.txt"):
        with open(file, "r") as f:
            data = f.read()
        lines = data.splitlines()
        idx = 4 if lines[4].split(": ")[0] == "num steps" else 5
        data_summary[pipeline.stem]["geo_dist"].append(float(lines[0].split(": ")[-1]))
        data_summary[pipeline.stem]["num_steps"].append(int(lines[idx].split(": ")[-1]))

for pipeline in data_summary:
    data_summary[pipeline]["geo_dist"] = np.mean(data_summary[pipeline]["geo_dist"])
    data_summary[pipeline]["num_steps"] = np.mean(data_summary[pipeline]["num_steps"])

plt.figure(figsize=(15, 8))
x = list(data_summary.keys())
y = [data_summary[pipeline]["geo_dist"] for pipeline in data_summary]
x = [x for _, x in sorted(zip(y, x))][::-1]
y = sorted(y)[::-1]

plt.bar(x, y)
plt.title("geo_dist")
plt.show()

plt.figure(figsize=(15, 8))
x = list(data_summary.keys())
y = [data_summary[pipeline]["num_steps"] for pipeline in data_summary]
x = [x for _, x in sorted(zip(y, x))][::-1]
y = sorted(y)[::-1]

plt.bar(x, y)
plt.title("num_steps")
plt.show()

# %%
data_summary
# Out:
# {'smplx_male_500': {'geo_dist': 0.01848602874411477,
#   'num_steps': 3367.777777777778},
#  'smplx_male_10k': {'geo_dist': 0.01996794053249889,
#   'num_steps': 3123.5555555555557},
#  'smplx_male_3k': {'geo_dist': 0.023381902939743467,
#   'num_steps': 2684.5555555555557},
#  'smplx_male_1k': {'geo_dist': 0.015049187621722618,
#   'num_steps': 3213.777777777778},
#  'smplx_male_7k': {'geo_dist': 0.018426156602799892,
#   'num_steps': 1593.4444444444443}}

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path


data_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/images_to_fit/smplx/male")
working_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/smplx_male/data_amount_ablation/1")
data_summary = {}
for pipeline in working_dir.iterdir():
    # if pipeline.stem == "1":
    #     continue
    if pipeline.stem not in data_summary:
        data_summary[pipeline.stem] = {"geo_dist": [], "num_steps": []}
    for file in pipeline.rglob("*.txt"):
        with open(file, "r") as f:
            data = f.read()
        lines = data.splitlines()
        idx = 4 if lines[4].split(": ")[0] == "num steps" else 5
        data_summary[pipeline.stem]["geo_dist"].append(float(lines[0].split(": ")[-1]))
        data_summary[pipeline.stem]["num_steps"].append(int(lines[idx].split(": ")[-1]))

for pipeline in data_summary:
    data_summary[pipeline]["geo_dist"] = np.mean(data_summary[pipeline]["geo_dist"])
    data_summary[pipeline]["num_steps"] = np.mean(data_summary[pipeline]["num_steps"])

plt.figure(figsize=(15, 8))
x = list(data_summary.keys())
y = [data_summary[pipeline]["geo_dist"] for pipeline in data_summary]
x = [x for _, x in sorted(zip(y, x))][::-1]
y = sorted(y)[::-1]

plt.bar(x, y)
plt.title("geo_dist")
plt.show()

# plt.figure(figsize=(15, 8))
# x = list(data_summary.keys())
# y = [data_summary[pipeline]["num_steps"] for pipeline in data_summary]
# x = [x for _, x in sorted(zip(y, x))][::-1]
# y = sorted(y)[::-1]

# plt.bar(x, y)
# plt.title("num_steps")
# plt.show()

# %%
data_summary

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path


data_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/images_to_fit/smplx/male")
working_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/smplx_male/data_amount_ablation/2")
data_summary2 = {}
for pipeline in working_dir.iterdir():
    # if pipeline.stem == "1":
    #     continue
    if pipeline.stem not in data_summary2:
        data_summary2[pipeline.stem] = {"geo_dist": [], "num_steps": []}
    for file in pipeline.rglob("*.txt"):
        with open(file, "r") as f:
            data = f.read()
        lines = data.splitlines()
        idx = 4 if lines[4].split(": ")[0] == "num steps" else 5
        data_summary2[pipeline.stem]["geo_dist"].append(float(lines[0].split(": ")[-1]))
        data_summary2[pipeline.stem]["num_steps"].append(int(lines[idx].split(": ")[-1]))

for pipeline in data_summary2:
    data_summary2[pipeline]["geo_dist"] = np.mean(data_summary2[pipeline]["geo_dist"])
    data_summary2[pipeline]["num_steps"] = np.mean(data_summary2[pipeline]["num_steps"])

plt.figure(figsize=(15, 8))
x = list(data_summary2.keys())
y = [data_summary2[pipeline]["geo_dist"] for pipeline in data_summary2]
x = [x for _, x in sorted(zip(y, x))][::-1]
y = sorted(y)[::-1]

plt.bar(x, y)
plt.title("geo_dist")
plt.show()

# plt.figure(figsize=(15, 8))
# x = list(data_summary.keys())
# y = [data_summary[pipeline]["num_steps"] for pipeline in data_summary]
# x = [x for _, x in sorted(zip(y, x))][::-1]
# y = sorted(y)[::-1]

# plt.bar(x, y)
# plt.title("num_steps")
# plt.show()

# %%
data_summary2
# Out:
# {'smplx_male_e2e': {'geo_dist': 0.023381902939743467,
#   'num_steps': 2684.5555555555557},
#  'smplx_male_10k': {'geo_dist': 0.015442160268624624,
#   'num_steps': 4034.8888888888887},
#  'smplx_male_1k': {'geo_dist': 0.0247039750425352,
#   'num_steps': 2932.777777777778}}

# %%
data_summary
# Out:
# {'smplx_male_e2e': {'geo_dist': 0.023381902939743467,
#   'num_steps': 2684.5555555555557},
#  'smplx_male_10k': {'geo_dist': 0.015442160268624624,
#   'num_steps': 4034.8888888888887},
#  'smplx_male_1k': {'geo_dist': 0.0247039750425352,
#   'num_steps': 2932.777777777778}}

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

data_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_bldata_summary = {}
for pipeline in working_dir.iterdir():
    if pipeline.stem not in data_summary:
        data_summary[pipeline.stem] = {"geo_dist": [], "num_steps": []}
    for file in pipeline.rglob("*.txt"):
        with open(file, "r") as f:
            data = f.read()
        lines = data.splitlines()
        idx = 4 if lines[4].split(": ")[0] == "num steps" else 5
        data_summary[pipeline.stem]["geo_dist"].append(float(lines[0].split(": ")[-1]))
        data_summary[pipeline.stem]["num_steps"].append(int(lines[idx].split(": ")[-1]))

for pipeline in data_summary:
    data_summary[pipeline]["geo_dist"] = np.mean(data_summary[pipeline]["geo_dist"])
    data_summary[pipeline]["num_steps"] = np.mean(data_summary[pipeline]["num_steps"])

plt.figure(figsize=(15, 8))
x = list(data_summary.keys())
y = [data_summary[pipeline]["geo_dist"] for pipeline in data_summary]
x = [x for _, x in sorted(zip(y, x))][::-1]
y = sorted(y)[::-1]

plt.bar(x, y)
plt.title("geo_dist")
plt.show()

plt.figure(figsize=(15, 8))
x = list(data_summary.keys())
y = [data_summary[pipeline]["num_steps"] for pipeline in data_summary]
x = [x for _, x in sorted(zip(y, x))][::-1]
y = sorted(y)[::-1]

plt.bar(x, y)
plt.title("num_steps")
plt.show()
endshapes/images_to_fit")
working_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/smplx_male/data_amount_ablation/")

data_summary = {}
for img_id in data_dir.rglob("*.png"):
    img_id = img_id.stem
    data_summary[img_id] = {}
    for file in working_dir.rglob(f"{img_id}.txt"):
        with open(file, "r") as f:
            data = f.read()
        lines = data.splitlines()
        idx = 4 if lines[4].split(": ")[0] == "num_steps" else 5
        data_summary[img_id][file.parent.stem] = {"geo_dist": float(lines[0].split(": ")[-1])}#, "num_steps": int(lines[idx].split(": ")[-1])}

# for each descriptor, sum the geo_dist for all images
geo_dist = {}
for img_id in data_summary:
    for desc in data_summary[img_id]:
        if desc not in geo_dist:
            geo_dist[desc] = []
        geo_dist[desc].append(data_summary[img_id][desc]["geo_dist"])
geo_dist = {k: geo_dist[k] for k in ["smplx_male_multiview_500", "smplx_male_multiview_1K", "smplx_male_multiview_3k", "smplx_male_multiview_7K"]}
for desc in geo_dist:
    geo_dist[desc] = np.sqrt(np.array(geo_dist[desc]).mean())

# plot
plt.figure(figsize=(10, 5))
plt.bar(geo_dist.keys(), geo_dist.values(), color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"], width=0.5)
for i, v in enumerate(geo_dist.values()):
    plt.text(i, v, f"{v:.4f}", horizontalalignment="center", fontsize=12)
plt.title("Geometric Distance by # of Samples")
plt.tight_layout()

# plt.savefig("/home/nadav2/dev/data/CLIP2Shape/images/supplementary_material/plots/geo_dist_by_num_descriptors.png")

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

data_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/images_to_fit")
working_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/smplx_male/data_amount_ablation/")

data_summary = {}
for img_id in data_dir.rglob("*.png"):
    img_id = img_id.stem
    data_summary[img_id] = {}
    for file in working_dir.rglob(f"{img_id}.txt"):
        with open(file, "r") as f:
            data = f.read()
        lines = data.splitlines()
        idx = 4 if lines[4].split(": ")[0] == "num_steps" else 5
        data_summary[img_id][file.parent.stem] = {"geo_dist": float(lines[0].split(": ")[-1])}#, "num_steps": int(lines[idx].split(": ")[-1])}

# for each descriptor, sum the geo_dist for all images
geo_dist = {}
for img_id in data_summary:
    for desc in data_summary[img_id]:
        if desc not in geo_dist:
            geo_dist[desc] = []
        geo_dist[desc].append(data_summary[img_id][desc]["geo_dist"])
geo_dist = {k: geo_dist[k] for k in ["smplx_male_multiview_500", "smplx_male_multiview_1K", "smplx_male_multiview_3k", "smplx_male_multiview_7K", "smplx_male_multiview_10K"]}
for desc in geo_dist:
    geo_dist[desc] = np.sqrt(np.array(geo_dist[desc]).mean())

# plot
plt.figure(figsize=(15, 10))
plt.bar(geo_dist.keys(), geo_dist.values(), color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"], width=0.5)
for i, v in enumerate(geo_dist.values()):
    plt.text(i, v, f"{v:.4f}", horizontalalignment="center", fontsize=12)
plt.title("Geometric Distance by # of Samples")
plt.tight_layout()

# plt.savefig("/home/nadav2/dev/data/CLIP2Shape/images/supplementary_material/plots/geo_dist_by_num_descriptors.png")

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

data_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/images_to_fit")
working_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/smplx_male/num_view_ablation/")

data_summary = {}
for img_id in data_dir.rglob("*.png"):
    img_id = img_id.stem
    data_summary[img_id] = {}
    for file in working_dir.rglob(f"{img_id}.txt"):
        with open(file, "r") as f:
            data = f.read()
        lines = data.splitlines()
        idx = 4 if lines[4].split(": ")[0] == "num_steps" else 5
        data_summary[img_id][file.parent.stem] = {"geo_dist": float(lines[0].split(": ")[-1])}#, "num_steps": int(lines[idx].split(": ")[-1])}

# for each descriptor, sum the geo_dist for all images
geo_dist = {}
for img_id in data_summary:
    for desc in data_summary[img_id]:
        if desc not in geo_dist:
            geo_dist[desc] = []
        geo_dist[desc].append(data_summary[img_id][desc]["geo_dist"])
geo_dist = {k: geo_dist[k] for k in ["smplx_male_multiview_10K", "smplx_male_singleview_10K"]}
for desc in geo_dist:
    geo_dist[desc] = np.sqrt(np.array(geo_dist[desc]).mean())

# plot
plt.figure(figsize=(10, 5))
plt.bar(geo_dist.keys(), geo_dist.values(), color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"], width=0.5)
for i, v in enumerate(geo_dist.values()):
    plt.text(i, v, f"{v:.4f}", horizontalalignment="center", fontsize=12)
plt.title("Geometric Distance by # of Samples")
plt.tight_layout()

# plt.savefig("/home/nadav2/dev/data/CLIP2Shape/images/supplementary_material/plots/geo_dist_by_num_descriptors.png")

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

data_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/images_to_fit")
working_dir = Path("/home/nadav2/dev/data/CLIP2Shape/outs/sliders_vs_blendshapes/smplx_male/descriptors_ablations/")

data_summary = {}
for img_id in data_dir.rglob("*.png"):
    img_id = img_id.stem
    data_summary[img_id] = {}
    for file in working_dir.rglob(f"{img_id}.txt"):
        with open(file, "r") as f:
            data = f.read()
        lines = data.splitlines()
        idx = 4 if lines[4].split(": ")[0] == "num_steps" else 5
        data_summary[img_id][file.parent.stem] = {"geo_dist": float(lines[0].split(": ")[-1])}#, "num_steps": int(lines[idx].split(": ")[-1])}

# for each descriptor, sum the geo_dist for all images
geo_dist = {}
for img_id in data_summary:
    for desc in data_summary[img_id]:
        if desc not in geo_dist:
            geo_dist[desc] = []
        geo_dist[desc].append(data_summary[img_id][desc]["geo_dist"])
geo_dist = {k: geo_dist[k] for k in ["smplx_male_2_descriptors", "smplx_male_5_descriptors", "smplx_male_10_descriptors", "smplx_male_15_descriptors", "smplx_male_20_descriptors", "smplx_male_25_descriptors"]}
for desc in geo_dist:
    geo_dist[desc] = np.sqrt(np.array(geo_dist[desc]).mean())

# plot
plt.figure(figsize=(15, 5))
plt.bar(geo_dist.keys(), geo_dist.values(), color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"], width=0.5)
for i, v in enumerate(geo_dist.values()):
    plt.text(i, v, f"{v:.4f}", horizontalalignment="center", fontsize=12)
plt.title("Geometric Distance by # of Samples")
plt.tight_layout()

# plt.savefig("/home/nadav2/dev/data/CLIP2Shape/images/supplementary_material/plots/geo_dist_by_num_descriptors.png")
